# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh7406/tut-codes/blob/main/-2)%20notebooks/1)%20pandas/filtering_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Load Data (Replace with actual file path)
url="https://raw.githubusercontent.com/Rishabh7406/tut-codes/refs/heads/main/-1)%20datasets/Expanded_data_with_more_features.csv"
df = pd.read_csv(url)

# %% [markdown]
# ### Filtering Data ###

# %% [markdown]
# # 1. loc[]: Select rows based on conditions

# %%
# Example 1: Select students with MathScore above 80
df_loc_1 = df.loc[df['MathScore'] > 80]
display(df_loc_1.head())
# Out:
#     Unnamed: 0  Gender EthnicGroup          ParentEduc LunchType   TestPrep  \
# 2            2  female     group B     master's degree  standard       none
# 6            6  female     group B        some college  standard  completed
# 16          16    male     group C         high school  standard        NaN
# 33          34    male     group E        some college  standard       none
# 34          35    male     group E  associate's degree  standard  completed
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 2               single     sometimes          yes         4.0     school_bus
# 6              widowed         never           no         1.0        private
# 16             married     sometimes          yes         0.0     school_bus
# 33            divorced     sometimes          yes         0.0     school_bus
# 34              single     sometimes           no         NaN     school_bus
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore
# 2             < 5         87            93            91
# 6          5 - 10         85            93            89
# 16         5 - 10         88            89            86
# 33            NaN         97            87            82
# 34         5 - 10         81            81            79

# %%
# Example 2: Select female students who practice sports regularly
df_loc_2 = df.loc[(df['Gender'] == 'female') & (df['PracticeSport'] == 'regularly')]
display(df_loc_2.head())
# Out:
#     Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0            0  female         NaN   bachelor's degree      standard     none
# 5            5  female     group B  associate's degree      standard     none
# 9            9  female     group B         high school  free/reduced     none
# 12          12  female     group B         high school      standard     none
# 35          36  female     group D  associate's degree      standard     none
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0              married     regularly          yes         3.0     school_bus
# 5              married     regularly          yes         1.0     school_bus
# 9              married     regularly          yes         NaN        private
# 12             married     regularly           no         1.0        private
# 35             married     regularly           no         2.0        private
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0             < 5         71            71            74
# 5          5 - 10         73            84            79
# 9             < 5         37            59            50
# 12         5 - 10         66            82            74
# 35         5 - 10         76            82            85

# %% [markdown]
# # 2. iloc[]: Select rows based on index position

# %%
# Example 1: Select the first 5 rows
df_iloc_1 = df.iloc[:5]
display(df_iloc_1)
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75

# %%
# Example 2: Select rows 10 to 15 and columns 2 to 5
df_iloc_2 = df.iloc[10:15, 2:6]
display(df_iloc_2)
# Out:
#    EthnicGroup          ParentEduc LunchType   TestPrep
# 10     group C  associate's degree  standard       none
# 11     group D  associate's degree  standard       none
# 12     group B         high school  standard       none
# 13     group A        some college  standard  completed
# 14     group A     master's degree  standard       none

# %% [markdown]
# # 3. query(): Filters using SQL-like syntax

# %%
# Example 1: Select students who have more than 2 siblings
df_query_1 = df.query("NrSiblings > 2")
display(df_query_1.head())
# Out:
#     Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0            0  female         NaN   bachelor's degree      standard
# 2            2  female     group B     master's degree      standard
# 8            8    male     group D         high school  free/reduced
# 19          19  female     group C  associate's degree  free/reduced
# 20          20    male     group D         high school      standard
#
#      TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0        none             married     regularly          yes         3.0
# 2        none              single     sometimes          yes         4.0
# 8   completed              single     sometimes           no         3.0
# 19       none             married         never          yes         3.0
# 20       none             married     sometimes          yes         5.0
#
#    TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0      school_bus            < 5         71            71            74
# 2      school_bus            < 5         87            93            91
# 8         private           > 10         65            64            68
# 19        private            < 5         50            56            58
# 20     school_bus         5 - 10         66            69            63

# %%
# Example 2: Select students whose ParentEduc is "bachelor's degree"
df_query_2 = df.query('ParentEduc == "bachelor\'s degree"')
display(df_query_2.head())
# Out:
#      Unnamed: 0  Gender EthnicGroup         ParentEduc LunchType   TestPrep  \
# 0             0  female         NaN  bachelor's degree  standard       none
# 27           27  female     group C  bachelor's degree  standard       none
# 90           99  female     group D  bachelor's degree  standard       none
# 92          101    male     group D  bachelor's degree  standard  completed
# 105         114  female     group E  bachelor's degree  standard  completed
#
#     ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0               married     regularly          yes         3.0     school_bus
# 27              married     sometimes          yes         4.0     school_bus
# 90              married     regularly          yes         3.0     school_bus
# 92               single     sometimes           no         1.0        private
# 105             married     regularly          yes         3.0     school_bus
#
#     WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0              < 5         71            71            74
# 27            > 10         69            70            76
# 90             < 5         64            66            62
# 92          5 - 10         68            74            74
# 105            < 5         98            99           100

# %% [markdown]
# # 4. between(): Filters values within a range

# %%
# Example 1: Select students with MathScore between 60 and 80
df_between_1 = df[df['MathScore'].between(60, 80)]
display(df_between_1.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0           0  female         NaN   bachelor's degree      standard
# 1           1  female     group C        some college      standard
# 4           4    male     group C        some college      standard
# 5           5  female     group B  associate's degree      standard
# 8           8    male     group D         high school  free/reduced
#
#     TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0       none             married     regularly          yes         3.0
# 1        NaN             married     sometimes          yes         0.0
# 4       none             married     sometimes          yes         0.0
# 5       none             married     regularly          yes         1.0
# 8  completed              single     sometimes           no         3.0
#
#   TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0     school_bus            < 5         71            71            74
# 1            NaN         5 - 10         69            90            88
# 4     school_bus         5 - 10         76            78            75
# 5     school_bus         5 - 10         73            84            79
# 8        private           > 10         65            64            68

# %%
# Example 2: Select students with ReadingScore between 50 and 90
df_between_2 = df[df['ReadingScore'].between(50, 90)]
display(df_between_2.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
# 5           5  female     group B  associate's degree      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
# 5             married     regularly          yes         1.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75
# 5         5 - 10         73            84            79

# %% [markdown]
# # 5. mask(): Replaces values where conditions hold true

# %%
# Example 1: Mask MathScore < 50 with 'Low'
df_mask_1 = df.copy()
df_mask_1['MathScore'] = df_mask_1['MathScore'].mask(df_mask_1['MathScore'] < 50, 'Low')
display(df_mask_1.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours MathScore  ReadingScore  WritingScore
# 0            < 5        71            71            74
# 1         5 - 10        69            90            88
# 2            < 5        87            93            91
# 3         5 - 10       Low            56            42
# 4         5 - 10        76            78            75

# %%
# Example 2: Mask missing EthnicGroup values with 'Unknown'
df_mask_2 = df.copy()
df_mask_2['EthnicGroup'] = df_mask_2['EthnicGroup'].mask(df_mask_2['EthnicGroup'].isnull(), 'Unknown')
display(df_mask_2.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female     Unknown   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75
