# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh7406/tut-codes/blob/main/-2)%20notebooks/1)%20pandas/merging_joining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Merging and Combining Data ###

# %% [markdown]
# # Creating Sample DataFrames

# %%
left = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 90, 78, 88]
})

right = pd.DataFrame({
    'ID': [3, 4, 5, 6],
    'Name': ['Charlie', 'David', 'Eve', 'Frank'],
    'Grade': ['B', 'A', 'C', 'B']
})

display(left, right)
# Out:
#    ID     Name  Score
# 0   1    Alice     85
# 1   2      Bob     90
# 2   3  Charlie     78
# 3   4    David     88
#    ID     Name Grade
# 0   3  Charlie     B
# 1   4    David     A
# 2   5      Eve     C
# 3   6    Frank     B

# %% [markdown]
# # 1. merge(): Joining two datasets based on a common column

# %% [markdown]
# # Inner Join (Default) - Keeps only matching IDs

# %%
merged_inner = left.merge(right, on='ID', how='inner')
display(merged_inner)
# Out:
#    ID   Name_x  Score   Name_y Grade
# 0   3  Charlie     78  Charlie     B
# 1   4    David     88    David     A

# %% [markdown]
# # Left Join - Keeps all from left, fills NaN for missing data from right

# %%
grouped_left = left.merge(right, on='ID', how='left')
display(grouped_left)
# Out:
#    ID   Name_x  Score   Name_y Grade
# 0   1    Alice     85      NaN   NaN
# 1   2      Bob     90      NaN   NaN
# 2   3  Charlie     78  Charlie     B
# 3   4    David     88    David     A

# %% [markdown]
# # Outer Join - Keeps all records from both datasets

# %%
grouped_outer = left.merge(right, on='ID', how='outer')
display(grouped_outer)
# Out:
#    ID   Name_x  Score   Name_y Grade
# 0   1    Alice   85.0      NaN   NaN
# 1   2      Bob   90.0      NaN   NaN
# 2   3  Charlie   78.0  Charlie     B
# 3   4    David   88.0    David     A
# 4   5      NaN    NaN      Eve     C
# 5   6      NaN    NaN    Frank     B

# %% [markdown]
# # 2. concat(): Stacking datasets vertically or horizontally

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2']
})
df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5']
})

# %%
# Vertical Concatenation (axis=0)
df_concat_v = pd.concat([df1, df2], axis=0)
display(df_concat_v)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5

# %%
# Horizontal Concatenation (axis=1)
df3 = pd.DataFrame({
    'C': ['C0', 'C1', 'C2']
})

# %%
df_concat_h = pd.concat([df1, df3], axis=1)
display(df_concat_h)
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %% [markdown]
# # 3. join(): Similar to merge() but works on index

# %%
left_indexed = left.set_index('ID')
right_indexed = right.set_index('ID')

# %%
# Joining on index
joined_df = left_indexed.join(right_indexed, how='inner', lsuffix='_left', rsuffix='_right')
display(joined_df)
# Out:
#    Name_left  Score Name_right Grade
# ID
# 3    Charlie     78    Charlie     B
# 4      David     88      David     A

# %% [markdown]
# # 4. combine_first(): Filling missing values from another dataset

# %%
df_a = pd.DataFrame({
    'A': [np.nan, 2, np.nan, 4],
    'B': [5, np.nan, 7, np.nan]
})
df_b = pd.DataFrame({
    'A': [1, np.nan, 3, np.nan],
    'B': [np.nan, 6, np.nan, 8]
})

# %%
# Filling missing values using another DataFrame
df_combined = df_a.combine_first(df_b)
display(df_combined)
# Out:
#      A    B
# 0  1.0  5.0
# 1  2.0  6.0
# 2  3.0  7.0
# 3  4.0  8.0
