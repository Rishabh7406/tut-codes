# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh7406/tut-codes/blob/main/-2)%20notebooks/Pandas_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 5-Minute Pandas Tutorial
# ---
# 👋 **Welcome!** In this session, we'll explore the basics of Pandas using an **Employee Salary Dataset**.
#
# ## **🔹 What You Will Learn**
# - Creating a DataFrame
# - Exploring & Filtering Data
# - Sorting & Grouping
# - Adding New Columns
#
# 🚀 *Let's get started!*

# %% [markdown]
# ## **📌 Step 1: Import Pandas & Create a Dataset**

# %%
#import
import pandas as pd
# Creating Employee Data
data = {
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR'],
    'Salary': [50000, 70000, 65000, 72000, 48000],
    'Experience': [2, 5, 4, 6, 1]
}

# Convert to DataFrame
df=pd.DataFrame(data)

# Display DataFrame
df
# Out:
#   Employee Department  Salary  Experience
# 0    Alice         HR   50000           2
# 1      Bob         IT   70000           5
# 2  Charlie         IT   65000           4
# 3    David    Finance   72000           6
# 4      Eve         HR   48000           1

# %% [markdown]
# ## **📌 Step 2: Check Basic Info**

# %%
# Check data types & missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Employee    5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
#  3   Experience  5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
# Summary statistics
df.describe()
# Out:
#             Salary  Experience
# count      5.00000    5.000000
# mean   61000.00000    3.600000
# std    11269.42767    2.073644
# min    48000.00000    1.000000
# 25%    50000.00000    2.000000
# 50%    65000.00000    4.000000
# 75%    70000.00000    5.000000
# max    72000.00000    6.000000

# %% [markdown]
# ## **📌 Step 3: Selecting & Filtering Data**

# %%
# Select Salary column
df['Salary']
# Out:
# 0    50000
# 1    70000
# 2    65000
# 3    72000
# 4    48000
# Name: Salary, dtype: int64

# %%
# Filter employees earning > 60,000
df[df['Salary']>60000]
# Out:
#   Employee Department  Salary  Experience
# 1      Bob         IT   70000           5
# 2  Charlie         IT   65000           4
# 3    David    Finance   72000           6

# %% [markdown]
# ## **📌 Step 4: Sorting & Grouping**

# %%
# Sort employees by Salary
df.sort_values(by='Salary',ascending=False)
# Out:
#   Employee Department  Salary  Experience
# 3    David    Finance   72000           6
# 1      Bob         IT   70000           5
# 2  Charlie         IT   65000           4
# 0    Alice         HR   50000           2
# 4      Eve         HR   48000           1

# %%
# Avg Salary per department
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    72000.0
# HR         49000.0
# IT         67500.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## **📌 Step 5: Adding a New Column**

# %%
# 10% hike
df["Hike"]=df['Salary']*1.1
df
# Out:
#   Employee Department  Salary  Experience     Hike
# 0    Alice         HR   50000           2  55000.0
# 1      Bob         IT   70000           5  77000.0
# 2  Charlie         IT   65000           4  71500.0
# 3    David    Finance   72000           6  79200.0
# 4      Eve         HR   48000           1  52800.0

# %% [markdown]
# ## **📌 Conclusion**
# ---
# 🎯 **We Learned:**
# - Creating and exploring DataFrames
# - Filtering & sorting data
# - Grouping and modifying data
#
# 💡 **Next Steps:** Try more operations on this dataset and experiment with real-world data! 🚀

# %% [markdown]
# # contact :- dubeyrishabh108@gmail.com
